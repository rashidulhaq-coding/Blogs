# %%
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json

# %%
json_data = ''' 
[
    {
        "flow_rate": 10.3,
        "length": 49.7631241,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 38.54,
        "length": 2.8696498,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 82.53,
        "length": 75.29,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 38.54,
        "length": 2.8696498,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 82.53,
        "length": 75.29,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 42.3,
        "length": 74.56,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 88.31,
        "length": 35.2,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 71.1,
        "length": 101.01,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 85.34,
        "length": 99.86,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.86,
        "length": 118.05126472,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 38.36,
        "length": 65.8,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 62.04,
        "length": 10.71,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 58.93,
        "length": 15.44,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 31.35,
        "length": 119.18,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 46.71,
        "length": 123.06,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.07,
        "length": 22.8,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.92,
        "length": 54.48,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 98.35,
        "length": 142.4,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 78.57,
        "length": 41.61,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 53.79,
        "length": 13.26696699,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 55.25,
        "length": 77.87563103,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 92.96,
        "length": 135.21400734,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 42.72,
        "length": 59.74,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.88,
        "length": 76.76,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.18,
        "length": 96.99,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 26.62,
        "length": 88.55,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 44.06,
        "length": 130.46,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 89.6,
        "length": 12.98,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 74.73,
        "length": 119.3,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 41.26,
        "length": 113.18,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.65,
        "length": 84.57,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 55.58,
        "length": 141.04,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.02,
        "length": 89.89,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 88.96,
        "length": 8.01340939,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.77,
        "length": 45.67,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 92.6,
        "length": 6.2,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 38.93,
        "length": 120.06,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 74.4,
        "length": 108.91,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 41,
        "length": 66.10899753,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 31.56,
        "length": 1.81,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 53.73,
        "length": 54.1,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 37.55,
        "length": 40.97,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 73.24,
        "length": 135.38,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 28.66,
        "length": 101.56922498,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 94.72,
        "length": 28.95,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 94.9,
        "length": 71.63,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 22.17,
        "length": 112.84,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 79.05,
        "length": 52.39,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 74.4,
        "length": 108.91,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.59,
        "length": 73.4,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.2,
        "length": 12.1783168,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 92.9,
        "length": 94.7,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 62.61,
        "length": 93.32,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24.94,
        "length": 61.5,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.29,
        "length": 88.99,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.87,
        "length": 142.35,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 58.13,
        "length": 118.38,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 75.26,
        "length": 17.1,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 90.81,
        "length": 26.22,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 82.67,
        "length": 12.48889507,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 22.9,
        "length": 99.49,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 78.57,
        "length": 41.61,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.4,
        "length": 89.52,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 53.79,
        "length": 13.26696699,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 93.29,
        "length": 48.75,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 16.66,
        "length": 76.30669709,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 30.3,
        "length": 99.85,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 26.5,
        "length": 43.83,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 49.33,
        "length": 98.14,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.85,
        "length": 92.56,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 85.34,
        "length": 99.86,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 62.26,
        "length": 11.44,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 82.51,
        "length": 136.37,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 67.01,
        "length": 189.42,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 53.25,
        "length": 168.36,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.92,
        "length": 54.48,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 96.09,
        "length": 86.28,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 97.23,
        "length": 101.71,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 66.95,
        "length": 100.61,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 11.35,
        "length": 140.41,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 49.81,
        "length": 92.66,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.2,
        "length": 12.1783168,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 91.62,
        "length": 11.77429403,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 37.55,
        "length": 40.97,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 47.56,
        "length": 32.62,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 68.74,
        "length": 60.26,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 28.44,
        "length": 67.65,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 90.81,
        "length": 26.22,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 63.16,
        "length": 3.30927484,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 61.32,
        "length": 56.11,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.65,
        "length": 84.57,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 61.32,
        "length": 56.11,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 13.12,
        "length": 101.43,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 75.2,
        "length": 81.1,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 88.31,
        "length": 35.2,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 99.78,
        "length": 61.32,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 23.23,
        "length": 17.19,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 49.37,
        "length": 103.07,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 77.65,
        "length": 1.719,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 11.24,
        "length": 2.0239444,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 89.6,
        "length": 12.98,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 26.5,
        "length": 43.83,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 88.96,
        "length": 8.01340939,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 97.73,
        "length": 60.9,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 17.27,
        "length": 122.41,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24,
        "length": 119.4,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.86,
        "length": 118.05126472,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 47.33,
        "length": 60.35,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 54.95,
        "length": 58.65,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 52.26,
        "length": 72.32,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 51.31,
        "length": 120.66,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24.66,
        "length": 142.1,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 47.33,
        "length": 60.35,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.29,
        "length": 88.99,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.31,
        "length": 77.63,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 11.12,
        "length": 17.49,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 33.03,
        "length": 65.53,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.07,
        "length": 69.73,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.65,
        "length": 144.16,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 40.09,
        "length": 16.18,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 32.35,
        "length": 131.61,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 81.18,
        "length": 56.86,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 96.09,
        "length": 86.28,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 11.12,
        "length": 17.49,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 58.41,
        "length": 4.56869785,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 69.61,
        "length": 85.15,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.6,
        "length": 116.12,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.07,
        "length": 69.73,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 61.12,
        "length": 6.84404237,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.21,
        "length": 2.39044808,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 50.85,
        "length": 62.49,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.06,
        "length": 112.08,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 33.4,
        "length": 74.97,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 75.2,
        "length": 81.1,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.33,
        "length": 8.75501462,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.98,
        "length": 73.21,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 52.1,
        "length": 35.94,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 82.51,
        "length": 136.37,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 11.06,
        "length": 124.05,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 60.23,
        "length": 102.89,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 68.74,
        "length": 60.26,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 28.48,
        "length": 11.46845713,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.33,
        "length": 8.75501462,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 78.41,
        "length": 67.44,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 69.61,
        "length": 142.04,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 38.36,
        "length": 65.8,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 69.81,
        "length": 9.10105983,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 76.62,
        "length": 35.47,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 37.87,
        "length": 40.23,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 86.64,
        "length": 100.28,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 79.05,
        "length": 52.39,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 17.27,
        "length": 122.41,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.41,
        "length": 108.82,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.04,
        "length": 5.68,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 36.91,
        "length": 111.29,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 85.89,
        "length": 63.85,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 49.33,
        "length": 98.14,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 94.5,
        "length": 37.87,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 49.81,
        "length": 92.66,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 96.3,
        "length": 11.69,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.85,
        "length": 92.56,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 46.73,
        "length": 88.66,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 32.39,
        "length": 26.55,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 45.7,
        "length": 100.07606723,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.47,
        "length": 28.6,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 31.35,
        "length": 119.18,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24.68,
        "length": 140.5,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 79.24,
        "length": 32.36,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 27.07,
        "length": 44.24,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 99.78,
        "length": 61.32,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 21.31,
        "length": 130.71,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 33.8,
        "length": 16.46,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 29.22,
        "length": 48.77,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 61.79,
        "length": 128,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.52,
        "length": 104.92,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.4,
        "length": 89.52,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 46.86,
        "length": 19.54,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.87,
        "length": 16.22,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 62.04,
        "length": 10.71,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.88,
        "length": 76.76,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.06,
        "length": 112.08,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.02,
        "length": 89.89,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 95.22,
        "length": 62.51861017,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 26.05,
        "length": 86.99055365,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 51.31,
        "length": 120.66,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 93.01,
        "length": 142.23,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.84,
        "length": 124.04100955,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 86.64,
        "length": 100.28,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 55.25,
        "length": 77.87563103,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 90.43,
        "length": 12.74,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 89.37,
        "length": 22.2,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24,
        "length": 119.4,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 25.75,
        "length": 61.25,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.18,
        "length": 67.62,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 71.1,
        "length": 101.01,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 97.23,
        "length": 101.71,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.52,
        "length": 128.40991214,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.73,
        "length": 17.13716342,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 53.59,
        "length": 1.19605058,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 33.44,
        "length": 53.46,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.77,
        "length": 45.67,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 21.31,
        "length": 130.71,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.52,
        "length": 128.40991214,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 58.41,
        "length": 4.56869785,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 80.92,
        "length": 111.81,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 46.83,
        "length": 54.79,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.92,
        "length": 133.82,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 22.89,
        "length": 137.59,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.18,
        "length": 67.62,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14

        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 88.92,
        "length": 52.55,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 46.73,
        "length": 88.66,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.31,
        "length": 77.63,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 98.14,
        "length": 123.1788768,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 63.16,
        "length": 3.30927484,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 94.72,
        "length": 28.95,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 27.08,
        "length": 142.34,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 69.61,
        "length": 142.04,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 32.35,
        "length": 131.61,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 53.73,
        "length": 54.1,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.03,
        "length": 135.18,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 33.04,
        "length": 150.51,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 67.01,
        "length": 189.42,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 54.19,
        "length": 122.71,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 55.58,
        "length": 141.04,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 73.84,
        "length": 19.91080373,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.18,
        "length": 96.99,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 34.6,
        "length": 69.59,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 45.7,
        "length": 100.07606723,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 22.36,
        "length": 52.62818902,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 26.05,
        "length": 86.99055365,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 52.26,
        "length": 72.32,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 58.13,
        "length": 118.38,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 74.73,
        "length": 119.3,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 25.75,
        "length": 61.25,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 56.87,
        "length": 142.35,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 33.8,
        "length": 16.46,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 26.62,
        "length": 88.55,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 61.79,
        "length": 128,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 58.93,
        "length": 15.44,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 89.37,
        "length": 22.2,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 54.95,
        "length": 58.65,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.6,
        "length": 116.12,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24.66,
        "length": 142.1,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.04,
        "length": 5.68,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 44.06,
        "length": 130.46,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 12.39,
        "length": 55.47,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.52,
        "length": 104.92,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 69.61,
        "length": 85.15,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 48.5,
        "length": 70.4,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.65,
        "length": 144.16,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 59.9,
        "length": 136.96,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 93.29,
        "length": 48.75,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 87.47,
        "length": 53.41,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 26.85,
        "length": 136.13,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 91.81,
        "length": 13.83846816,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 91.62,
        "length": 11.77429403,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 80.92,
        "length": 111.81,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24.63,
        "length": 71.05,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 52.1,
        "length": 35.94,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 46.71,
        "length": 123.06,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.29,
        "length": 98.15,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.47,
        "length": 28.6,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 24.94,
        "length": 61.5,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 50.85,
        "length": 62.49,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 52.83,
        "length": 130.51,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 59.9,
        "length": 136.96,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 36.12,
        "length": 75.54,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 88.92,
        "length": 52.55,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 57.98,
        "length": 73.21,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 18.87,
        "length": 16.22,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 14.54,
        "length": 114.42,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 46.83,
        "length": 54.79,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 32.19,
        "length": 18.95,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 27.08,
        "length": 142.34,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 11.24,
        "length": 2.0239444,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.81,
        "length": 92.64,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 22.1,
        "length": 2.23,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 67.09,
        "length": 34.75,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 49.12,
        "length": 101.19,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 22.28,
        "length": 119.07,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 49.12,
        "length": 101.19,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.64,
        "length": 2.56,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 65.64,
        "length": 2.56,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 67.09,
        "length": 34.75,
        "timestamp": "2024-07-04 04:32:39"
    },
    {
        "flow_rate": 15.81,
        "length": 92.64,
        "timestamp": "2024-07-04 04:32:39"
    }
]
'''

# %%
df.describe()
# Out:
#         flow_rate      length
# count  389.000000  389.000000
# mean    51.918946   73.000271
# std     25.486648   44.798449
# min     10.300000    1.196051
# 25%     28.660000   35.200000
# 50%     52.830000   70.400000
# 75%     71.100000  111.290000
# max     99.780000  189.420000

# %%
data = json.loads(json_data)
df = pd.DataFrame(data)

# Find the minimum and maximum values of flow_rate
min_flow_rate = df['flow_rate'].min()
max_flow_rate = df['flow_rate'].max()

# Calculate the range
flow_rate_range = max_flow_rate - min_flow_rate

# Define the number of intervals (bins)
num_intervals = 5

# Calculate the interval size
interval = flow_rate_range/num_intervals
min_flow_rate , max_flow_rate, interval
# Out:
# (10.3, 99.78, 17.896)

# %%
df['length_divided_by_range'] = df['length'] / flow_rate_range

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['flow_rate'], df['length_divided_by_range'], width=1.0, align='center')

# Set the x-ticks
xticks = np.arange(10.3, 99.78, 17.896)
plt.xticks(xticks)

# Set the labels and title
plt.xlabel('Flow Rate')
plt.ylabel('Length Divided by Range')
plt.title('Histogram of Flow Rate vs. Length Divided by Range')

# Show the plot
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Deep learning\Potato Disease prediction\env\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'length_divided_by_range'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head()
# Out:
#    flow_rate     length            timestamp  length_divided_by_range
# 0      10.30  49.763124  2024-07-04 04:32:39                 0.556137
# 1      38.54   2.869650  2024-07-04 04:32:39                 0.032070
# 2      82.53  75.290000  2024-07-04 04:32:39                 0.841417
# 3      38.54   2.869650  2024-07-04 04:32:39                 0.032070
# 4      82.53  75.290000  2024-07-04 04:32:39                 0.841417

# %%
# Generate synthetic data for two classes
num_samples = 2000
class_0_samples = np.random.multivariate_normal(
    mean=[0, 4],
    cov=[[1, 0.4], [0.4, 1]],
    size=num_samples
)
class_1_samples = np.random.multivariate_normal(
    mean=[4, 0],
    cov=[[1, 0.4], [0.4, 1]],
    size=num_samples
)

# Combine the samples and create corresponding labels
features = np.vstack((class_0_samples, class_1_samples)).astype(np.float32)
labels = np.vstack((
    np.zeros((num_samples, 1), dtype=np.float32),
    np.ones((num_samples, 1), dtype=np.float32)
))

# %%
plt.scatter(features[:, 0], features[:, 1], c=labels[:, 0])
plt.show()

# %%
# Define the model parameters
input_dim = features.shape[1]
output_dim = 1
weights = tf.Variable(tf.random.uniform((input_dim, output_dim)))
bias = tf.Variable(tf.zeros((output_dim,)))

# %%
# Define the model
def logistic_model(inputs,train=False):
    z = tf.add(tf.matmul(inputs, weights), bias)
    if train:
      return z
    return tf.sigmoid(z)

# Define the loss function
def binary_crossentropy_loss(true_values, predicted_values):
    return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=true_values, logits=predicted_values))

# %%
# Define the training step
learning_rate = 0.1
def train_step(features, labels):
    with tf.GradientTape() as tape:
        logits = logistic_model(features,train=True)
        loss = binary_crossentropy_loss(labels, logits)
    gradients = tape.gradient(loss, [weights, bias])
    weights.assign_sub(gradients[0] * learning_rate)
    bias.assign_sub(gradients[1] * learning_rate)
    return loss

# %%
# Define the accuracy function
def accuracy(true_values, predicted_values):
    predicted_classes = tf.cast(predicted_values > 0.5, tf.float32)
    correct_predictions = tf.cast(tf.equal(predicted_classes, true_values), tf.float32)
    return tf.reduce_mean(correct_predictions)

# %%
# Train the model and calculate accuracy
num_steps = 10
for step in range(num_steps):
    loss_value = train_step(features, labels)
    predictions = logistic_model(features)
    acc_value = accuracy(labels, predictions)
    print(f"Loss at step {step}: {loss_value:.4f}, Accuracy: {acc_value:.4f}")
# Out:
# Loss at step 0: 0.6626, Accuracy: 0.8763
# Loss at step 1: 0.4929, Accuracy: 0.9915
# Loss at step 2: 0.3859, Accuracy: 0.9980
# Loss at step 3: 0.3157, Accuracy: 0.9990
# Loss at step 4: 0.2671, Accuracy: 0.9995
# Loss at step 5: 0.2318, Accuracy: 0.9995
# Loss at step 6: 0.2051, Accuracy: 0.9995
# Loss at step 7: 0.1841, Accuracy: 0.9995
# Loss at step 8: 0.1672, Accuracy: 0.9995
# Loss at step 9: 0.1533, Accuracy: 0.9995
